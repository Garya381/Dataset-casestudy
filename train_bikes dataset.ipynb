# %% [markdown]
# # Importing libraries:

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

# %% [markdown]
# # Importing the data:

# %%
df=pd.read_csv('train_bikes.csv')

# %% [markdown]
# # Data Exploring:

# %%
df.head(5)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %% [markdown]
# # Data Fields:

# %% [markdown]
# * Datetime  :- hourly date + timestamp
# * Season    :- 1 = spring, 2 = summer, 3 = fall, 4 = winter
# * Holiday   :- whether the day is considered a holiday
# * Workingday - whether the day is neither a weekend nor holiday
# * weather   :-
#           1: Clear, Few clouds, Partly cloudy, Partly cloudy
#           2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#           3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#           4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# * Temp      :- temperature in Celsius
# * atemp     :- "feels like" temperature in Celsius
# * humidity  :- relative humidity
# * windspeed :- wind speed
# * casual    :- number of non-registered user rentals initiated
# * registered:- number of registered user rentals initiated
# * count     :- number of total rentals

# %%
df['datetime']=pd.to_datetime(df['datetime'])

# %%
df.plot.scatter(x='holiday',y='count');

# %% [markdown]
# we can see that in above chart more bikes are renting in holidays.

# %%
df.plot.scatter(x='workingday',y='count');

# %% [markdown]
# Similary people are renting more bikes in working days

# %%
df.plot.scatter(x='weather',y='count');

# %% [markdown]
# We can see that more bikes are renting in 1 weather category.

# %%
df.plot.scatter(x='temp',y='count');

# %% [markdown]
# We can see that when temprature becomes hight i.e 40 people are renting less bike

# %%
df.plot.scatter(x = 'windspeed', y = 'count')
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='count'>

# %% [markdown]
# When wind becomes high the bike renting also start reducing.

# %%
df.head(2)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40

# %%
sns.set(style='darkgrid')
sns.relplot(x='humidity', y='count',data=df)

# %%
plt.bar(df['season'],df['count'])
# Out:
# <BarContainer object of 10886 artists>

# %% [markdown]
# People are renting more bikes in season 3.

# %%
dfcopy=df.copy() 
dfcopy=dfcopy[dfcopy.datetime.dt.year==2012]
dfcopy.head()
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 5422 2012-01-01 00:00:00       1        0           0        1  14.76  18.940
# 5423 2012-01-01 01:00:00       1        0           0        1  14.76  17.425
# 5424 2012-01-01 02:00:00       1        0           0        1  13.12  17.425
# 5425 2012-01-01 03:00:00       1        0           0        1  12.30  16.665
# 5426 2012-01-01 04:00:00       1        0           0        1  11.48  15.150
#
#       humidity  windspeed  casual  registered  count
# 5422        66     0.0000       5          43     48
# 5423        66     8.9981      15          78     93
# 5424        76     0.0000      16          59     75
# 5425        81     0.0000      11          41     52
# 5426        81     6.0032       0           8      8

# %%
dfcopy.loc[:, ('hour')] = dfcopy.datetime.dt.hour
dfcopy.head()
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 5422 2012-01-01 00:00:00       1        0           0        1  14.76  18.940
# 5423 2012-01-01 01:00:00       1        0           0        1  14.76  17.425
# 5424 2012-01-01 02:00:00       1        0           0        1  13.12  17.425
# 5425 2012-01-01 03:00:00       1        0           0        1  12.30  16.665
# 5426 2012-01-01 04:00:00       1        0           0        1  11.48  15.150
#
#       humidity  windspeed  casual  registered  count  hour
# 5422        66     0.0000       5          43     48     0
# 5423        66     8.9981      15          78     93     1
# 5424        76     0.0000      16          59     75     2
# 5425        81     0.0000      11          41     52     3
# 5426        81     6.0032       0           8      8     4

# %%
d =dfcopy.groupby(['hour', 'season'])['count'].sum().unstack()
d
# Out:
# season      1      2      3      4
# hour
# 0        2185   3948   5075   3991
# 1        1467   2368   2958   2515
# 2        1023   1512   1998   1459
# 3         523    749    987    710
# 4         235    418    551    498
# 5         876   1415   1803   1589
# 6        3494   5816   6628   5703
# 7       10217  16691  18130  16266
# 8       19834  27992  28031  29054
# 9       11654  17676  17424  16817
# 10       7951  13997  15269  12516
# 11       9753  17409  17711  15441
# 12      12245  20523  21004  19377
# 13      12692  20919  20828  19338
# 14      11953  19703  19563  18184
# 15      12521  20754  20166  19723
# 16      15076  25429  25402  24344
# 17      21949  38322  38970  33837
# 18      20570  35704  37199  29573
# 19      14221  26294  28536  20904
# 20       9971  18785  21118  14812
# 21       7634  13875  15878  11091
# 22       5816  10881  12003   8537
# 23       3507   7096   8182   6161

# %% [markdown]
# # Bar chart for evaulating 2012 count as per the hours in different seasons:

# %%
d.plot(kind='bar',figsize=(22,5), width=0.9, title="2012");

# %% [markdown]
# In above chart the highest count is coming in 17th hour of season 3rd and the lowest count is occur in 4th hour of season 1th.

# %%
d11=df.copy()
d11=d11[d11.datetime.dt.year==2011]
d11.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
d11.loc[:,('hour')]=d11.datetime.dt.hour
d11.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour
# 0        81        0.0       3          13     16     0
# 1        80        0.0       8          32     40     1
# 2        80        0.0       5          27     32     2
# 3        75        0.0       3          10     13     3
# 4        75        0.0       0           1      1     4

# %%
dh1=d11.groupby(['hour','season'])['count'].sum().unstack()

# %%
dh1
# Out:
# season      1      2      3      4
# hour
# 0        1012   2718   3552   2607
# 1         653   1695   2108   1608
# 2         390   1165   1585   1127
# 3         222    563    796    541
# 4         102    331    371    326
# 5         257    908   1130    957
# 6        1334   3644   4405   3674
# 7        3844   9787  11970  10063
# 8        8794  16490  17969  16896
# 9        5798   9718  11157  10666
# 10       3594   7974   9644   8722
# 11       4101   9846  11573  10023
# 12       5358  12084  13996  12381
# 13       5636  12140  13876  12122
# 14       5291  11300  13081  11935
# 15       5615  11783  13459  11939
# 16       6429  15515  16929  15142
# 17      10365  23274  25484  21556
# 18       8860  21243  24255  19068
# 19       5879  16107  18603  13223
# 20       4210  11684  13976   9648
# 21       3230   8844  11028   7477
# 22       2496   6697   8607   5874
# 23       1661   4496   5694   4019

# %% [markdown]
# # Bar chart for evaulating 2011 count as per the hours in different seasons:

# %%
dh1.plot(kind='bar',figsize=(22,5), width=0.9, title="2011");

# %% [markdown]
# Similarly in 2011 the highest count is coming from 17th hour of season 3rd and the lowest count is occur in 3th hour of season 1th.

# %%
dm= df.copy()
dm['year'] = dm.datetime.dt.year
dm['month'] = dm.datetime.dt.month 
dm = dm.groupby(['month', 'year'])['count'].sum().unstack()
dm.head(20)
# Out:
# year    2011    2012
# month
# 1      23552   56332
# 2      32844   66269
# 3      38735   94766
# 4      50517  116885
# 5      79713  120434
# 6      89776  130957
# 7      92848  121769
# 8      83296  130220
# 9      79104  133425
# 10     79522  127912
# 11     70889  105551
# 12     61183   98977

# %% [markdown]
# # Barchart for comparing both years according to monthly counts:

# %%
dm.plot(kind='bar',  figsize=(15,5), title="2011,2012");
